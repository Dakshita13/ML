# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-be82a142-5193-4e33-bf87-511dabc02648" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be82a142-5193-4e33-bf87-511dabc02648">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving practise_data_set.csv to practise_data_set (1).csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("practise_data_set (1).csv")

# %%
data
# Out:
#     S.no Precip Type  Temperature  Apparent_Temperature   Humidity  \
# 0      1        rain     9.472222               7.388889      0.89
# 1      2        rain     9.355556               7.227778      0.86
# 2      3        rain     9.377778               9.377778      0.89
# 3      4        rain     8.288889               5.944444      0.83
# 4      5        rain     8.755556               6.977778      0.83
# 5      6        rain     9.222222               7.111111      0.85
# 6      7        rain     7.733333               5.522222      0.95
# 7      8        rain     8.772222               6.527778      0.89
# 8      9        rain    10.822222              10.822222      0.82
# 9     10        rain    13.772222              13.772222      0.72
# 10    11        rain    16.016667              16.016667      0.67
# 11    12        rain    17.144444              17.144444      0.54
# 12    13        rain    17.800000              17.800000      0.55
# ...

# %%
x=data.Humidity	
y=data.Temperature

# %%
plt.plot(y)
plt.show()
